# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('melb_data.csv')

# %%
df.head(3)
# Out:
#        Suburb          Address  Rooms Type    Price Method SellerG       Date  \
# 0  Abbotsford     85 Turner St      2    h  1480000      S  Biggin  3/12/2016
# 1  Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin   4/2/2016
# 2  Abbotsford     5 Charles St      3    h  1465000     SP  Biggin   4/3/2017
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5      3067  ...         1  1.0       202           NaN        NaN
# 1       2.5      3067  ...         1  0.0       156          79.0     1900.0
# 2       2.5      3067  ...         2  0.0       134         150.0     1900.0
#
#    CouncilArea Lattitude  Longtitude             Regionname Propertycount
# 0        Yarra  -37.7996    144.9984  Northern Metropolitan          4019
# 1        Yarra  -37.8079    144.9934  Northern Metropolitan          4019
# 2        Yarra  -37.8093    144.9944  Northern Metropolitan          4019
#
# [3 rows x 21 columns]

# %%
pd.set_option('max_columns',None)

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
#first condition : if null values in row : more than 5% then delete those
#rows

# %%
x=list(df[((df.isnull().sum(axis=1)/df.shape[1])*100)>5].index)

# %%
type(x)
# Out:
# list

# %%
print(x)
# Out:
# [0, 3, 5, 8, 10, 13, 14, 18, 26, 30, 45, 54, 55, 59, 62, 66, 70, 72, 73, 74, 75, 76, 79, 84, 86, 89, 91, 93, 94, 96, 97, 104, 109, 110, 111, 112, 114, 116, 118, 122, 127, 128, 129, 130, 135, 137, 139, 145, 148, 150, 155, 157, 160, 165, 167, 170, 172, 173, 174, 176, 177, 178, 180, 182, 183, 188, 190, 192, 197, 199, 202, 203, 205, 211, 212, 214, 215, 216, 218, 219, 222, 226, 228, 230, 232, 235, 237, 238, 242, 243, 247, 250, 252, 253, 254, 255, 258, 260, 264, 265, 270, 276, 278, 279, 281, 283, 297, 302, 303, 307, 309, 319, 328, 329, 330, 334, 338, 340, 341, 342, 352, 359, 360, 361, 363, 364, 368, 369, 372, 375, 387, 389, 391, 399, 405, 406, 409, 410, 414, 417, 418, 421, 425, 428, 432, 442, 445, 446, 447, 449, 450, 452, 454, 456, 457, 458, 459, 460, 461, 462, 465, 469, 474, 476, 477, 480, 481, 484, 487, 488, 491, 498, 504, 505, 516, 518, 520, 522, 523, 527, 533, 537, 539, 544, 547, 549, 553, 554, 556, 560, 562, 563, 566, 567, 568, 573, 576, 578, 580, 584, 588, 589, 596, 601, 602, 604, 60
# ...

# %%
len(x) #no. of records
# Out:
# 5248

# %%
for i in x:
    df=df.drop(i)

# %%
df.shape
# Out:
# (8332, 21)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea     1252
# YearBuilt         250
# CouncilArea       634
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price             0.000000
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          0.000000
# Bathroom          0.000000
# Car               0.000000
# Landsize          0.000000
# BuildingArea     15.026404
# YearBuilt         3.000480
# CouncilArea       7.609217
# Lattitude         0.000000
# Longtitude        0.000000
# Regionname        0.000000
# Propertycount     0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6196 entries, 1 to 12212
# Data columns (total 21 columns):
# Suburb           6196 non-null object
# Address          6196 non-null object
# Rooms            6196 non-null int64
# Type             6196 non-null object
# Method           6196 non-null object
# SellerG          6196 non-null object
# Date             6196 non-null object
# Distance         6196 non-null float64
# Postcode         6196 non-null int64
# Bedroom2         6196 non-null int64
# Bathroom         6196 non-null int64
# Car              6196 non-null float64
# Landsize         6196 non-null int64
# BuildingArea     6196 non-null float64
# YearBuilt        6196 non-null float64
# CouncilArea      6196 non-null object
# Lattitude        6196 non-null float64
# Longtitude       6196 non-null float64
# Regionname       6196 non-null object
# Propertycount    6196 non-null int64
# Price            6196 non-null int64
# dtypes: float64(6), int64(7), object(8)
# ...

# %%
x=list(df[((df.isnull().sum(axis=1)/df.shape[1])*100)>0].index)

# %%
for i in x:
    df=df.drop(i)

# %%
df.shape
# Out:
# (6196, 21)

# %%
plt.figure()
sns.heatmap(df.isnull())
plt.show()

# %%
df.head()
# Out:
#        Suburb          Address  Rooms Type    Price Method SellerG       Date  \
# 1  Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin   4/2/2016
# 2  Abbotsford     5 Charles St      3    h  1465000     SP  Biggin   4/3/2017
# 4  Abbotsford      55a Park St      4    h  1600000     VB  Nelson   4/6/2016
# 6  Abbotsford     124 Yarra St      3    h  1876000      S  Nelson   7/5/2016
# 7  Abbotsford    98 Charles St      2    h  1636000      S  Nelson  8/10/2016
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 1       2.5      3067         2         1  0.0       156          79.0
# 2       2.5      3067         3         2  0.0       134         150.0
# 4       2.5      3067         3         1  2.0       120         142.0
# 6       2.5      3067         4         2  0.0       245         210.0
# 7       2.5      3067         2         1  2.0       256         107.0
#
# ...

# %%
df.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.533505  0.283885  0.051237  0.951793  0.613853
# Price          0.533505  1.000000 -0.148867  0.125539  0.514561  0.503922
# Distance       0.283885 -0.148867  1.000000  0.405729  0.290242  0.124530
# Postcode       0.051237  0.125539  0.405729  1.000000  0.053770  0.109804
# Bedroom2       0.951793  0.514561  0.290242  0.053770  1.000000  0.617751
# Bathroom       0.613853  0.503922  0.124530  0.109804  0.617751  1.000000
# Car            0.422526  0.261507  0.273615  0.043713  0.425726  0.340808
# Landsize       0.098755  0.081419  0.059369  0.025807  0.097172  0.076295
# BuildingArea   0.608215  0.530574  0.159603  0.078483  0.593000  0.534425
# YearBuilt     -0.068122 -0.304633  0.246291  0.024375 -0.056343  0.157820
# Lattitude      0.016049 -0.213574 -0.094494 -0.425172  0.021309 -0.072020
# Longtitude     0.088031  0.211760  0.221861  0.471305  0.085895  0.116103
# ...

# %%
x=df['Price']

# %%
df=df.drop('Price',axis=1)

# %%
df['Price']=x

# %%
df.corr()
# Out:
#                   Rooms  Distance  Postcode  Bedroom2  Bathroom       Car  \
# Rooms          1.000000  0.283885  0.051237  0.951793  0.613853  0.422526
# Distance       0.283885  1.000000  0.405729  0.290242  0.124530  0.273615
# Postcode       0.051237  0.405729  1.000000  0.053770  0.109804  0.043713
# Bedroom2       0.951793  0.290242  0.053770  1.000000  0.617751  0.425726
# Bathroom       0.613853  0.124530  0.109804  0.617751  1.000000  0.340808
# Car            0.422526  0.273615  0.043713  0.425726  0.340808  1.000000
# Landsize       0.098755  0.059369  0.025807  0.097172  0.076295  0.117647
# BuildingArea   0.608215  0.159603  0.078483  0.593000  0.534425  0.334282
# YearBuilt     -0.068122  0.246291  0.024375 -0.056343  0.157820  0.108714
# Lattitude      0.016049 -0.094494 -0.425172  0.021309 -0.072020  0.011973
# Longtitude     0.088031  0.221861  0.471305  0.085895  0.116103  0.054699
# Propertycount -0.111422 -0.083969  0.064534 -0.109401 -0.067126 -0.046487
# ...

# %%
df.head()
# Out:
#        Suburb          Address  Rooms Type Method SellerG       Date  \
# 1  Abbotsford  25 Bloomburg St      2    h      S  Biggin   4/2/2016
# 2  Abbotsford     5 Charles St      3    h     SP  Biggin   4/3/2017
# 4  Abbotsford      55a Park St      4    h     VB  Nelson   4/6/2016
# 6  Abbotsford     124 Yarra St      3    h      S  Nelson   7/5/2016
# 7  Abbotsford    98 Charles St      2    h      S  Nelson  8/10/2016
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 1       2.5      3067         2         1  0.0       156          79.0
# 2       2.5      3067         3         2  0.0       134         150.0
# 4       2.5      3067         3         1  2.0       120         142.0
# 6       2.5      3067         4         2  0.0       245         210.0
# 7       2.5      3067         2         1  2.0       256         107.0
#
#    YearBuilt CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6196 entries, 1 to 12212
# Data columns (total 21 columns):
# Suburb           6196 non-null object
# Address          6196 non-null object
# Rooms            6196 non-null int64
# Type             6196 non-null object
# Method           6196 non-null object
# SellerG          6196 non-null object
# Date             6196 non-null object
# Distance         6196 non-null float64
# Postcode         6196 non-null int64
# Bedroom2         6196 non-null int64
# Bathroom         6196 non-null int64
# Car              6196 non-null float64
# Landsize         6196 non-null int64
# BuildingArea     6196 non-null float64
# YearBuilt        6196 non-null float64
# CouncilArea      6196 non-null object
# Lattitude        6196 non-null float64
# Longtitude       6196 non-null float64
# Regionname       6196 non-null object
# Propertycount    6196 non-null int64
# Price            6196 non-null int64
# dtypes: float64(6), int64(7), object(8)
# ...

# %%
catdf=df.select_dtypes(object)
numdf=df.select_dtypes(['int64','float64'])

# %%
numdf.head()
# Out:
#    Rooms  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 1      2       2.5      3067         2         1  0.0       156          79.0
# 2      3       2.5      3067         3         2  0.0       134         150.0
# 4      4       2.5      3067         3         1  2.0       120         142.0
# 6      3       2.5      3067         4         2  0.0       245         210.0
# 7      2       2.5      3067         2         1  2.0       256         107.0
#
#    YearBuilt  Lattitude  Longtitude  Propertycount    Price
# 1     1900.0   -37.8079    144.9934           4019  1035000
# 2     1900.0   -37.8093    144.9944           4019  1465000
# 4     2014.0   -37.8072    144.9941           4019  1600000
# 6     1910.0   -37.8024    144.9993           4019  1876000
# 7     1890.0   -37.8060    144.9954           4019  1636000

# %%
catdf.head()
# Out:
#        Suburb          Address Type Method SellerG       Date CouncilArea  \
# 1  Abbotsford  25 Bloomburg St    h      S  Biggin   4/2/2016       Yarra
# 2  Abbotsford     5 Charles St    h     SP  Biggin   4/3/2017       Yarra
# 4  Abbotsford      55a Park St    h     VB  Nelson   4/6/2016       Yarra
# 6  Abbotsford     124 Yarra St    h      S  Nelson   7/5/2016       Yarra
# 7  Abbotsford    98 Charles St    h      S  Nelson  8/10/2016       Yarra
#
#               Regionname
# 1  Northern Metropolitan
# 2  Northern Metropolitan
# 4  Northern Metropolitan
# 6  Northern Metropolitan
# 7  Northern Metropolitan

# %%
df.shape
# Out:
# (6196, 21)

# %%
numdf.shape
# Out:
# (6196, 13)

# %%
catdf.shape
# Out:
# (6196, 8)

# %%
numdf
# Out:
#        Rooms  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 1          2       2.5      3067         2         1  0.0       156
# 2          3       2.5      3067         3         2  0.0       134
# 4          4       2.5      3067         3         1  2.0       120
# 6          3       2.5      3067         4         2  0.0       245
# 7          2       2.5      3067         2         1  2.0       256
# 9          2       2.5      3067         3         1  2.0       220
# 11         3       2.5      3067         3         2  2.0       214
# 12         2       2.5      3067         2         2  1.0         0
# 15         2       2.5      3067         2         1  2.0       238
# 16         3       2.5      3067         3         2  1.0       113
# 17         3       2.5      3067         2         1  1.0       138
# 19         2       2.5      3067         2         1  1.0       150
# 20         4       2.5      3067         4         2  2.0       780
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in catdf:
    catdf[i]=le.fit_transform(catdf[i])

# %%
newdf=pd.concat([catdf,numdf],axis=1)

# %%
newdf.corr()
# Out:
#                  Suburb   Address      Type    Method   SellerG      Date  \
# Suburb         1.000000  0.024420  0.025932  0.044450  0.037319 -0.001790
# Address        0.024420  1.000000 -0.082517  0.019083 -0.014282  0.009776
# Type           0.025932 -0.082517  1.000000  0.089453  0.028784  0.009655
# Method         0.044450  0.019083  0.089453  1.000000 -0.011475 -0.008999
# SellerG        0.037319 -0.014282  0.028784 -0.011475  1.000000  0.008119
# Date          -0.001790  0.009776  0.009655 -0.008999  0.008119  1.000000
# CouncilArea    0.042183  0.003930  0.095130  0.028821  0.001324  0.013329
# Regionname     0.002561  0.027305  0.050107  0.026923  0.016172  0.003446
# Rooms         -0.067093  0.041700 -0.584355 -0.054857 -0.018201 -0.033310
# Distance      -0.043662 -0.057880 -0.227822 -0.053841  0.011822 -0.016722
# Postcode      -0.064733 -0.004576  0.026401 -0.031079 -0.010769 -0.001120
# Bedroom2      -0.063625  0.041206 -0.572275 -0.051046 -0.020378 -0.038625
# ...

# %%
# After Analysis Rooms and BuildingArea is important

# %% [markdown]
# # Single Linear Regression

# %%
x=df[['Rooms']]
y=df['Price']

# %%
plt.figure()
sns.boxplot(data=df,x='Price')
plt.show()

# %%
df['Price'].max()
# Out:
# 9000000

# %%
df['Rooms'].max()
# Out:
# 8

# %%
df['BuildingArea'].max()
# Out:
# 3112.0

# %%
plt.figure()
sns.boxplot(data=df,x='BuildingArea')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Single Linear Regression with Rooms Feature
x=newdf[['Rooms']]
y=newdf['Price']
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=1)
sl1=LinearRegression()
sl1.fit(X_train,Y_train)
Y_predict=sl1.predict(X_test)
print(sl1.score(X_train,Y_train))
print(sl1.score(X_test,Y_test))
# Out:
# 0.2905190573857688
# 0.2714240602779924

# %%
#Single Linear Regression with BuildingArea Feature
x=newdf[['BuildingArea']]
y=newdf['Price']
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=1)
sl2=LinearRegression()
sl2.fit(X_train,Y_train)
Y_predict=sl2.predict(X_test)
print(sl2.score(X_train,Y_train))
print(sl2.score(X_test,Y_test))
# Out:
# 0.2790757514474159
# 0.2841639736591932

# %% [markdown]
# # Multiple Linear Regression with Rooms and BuildingArea

# %%
#Multiple Linear Regression with Rooms and BuildingArea Features
x=newdf[['Rooms','BuildingArea']]
y=newdf['Price']
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=1)
ml1=LinearRegression()
ml1.fit(X_train,Y_train)
Y_predict=ml1.predict(X_test)
print(ml1.score(X_train,Y_train))
print(ml1.score(X_test,Y_test))
# Out:
# 0.3553183286889443
# 0.34332949200280516

# %%
#Multiple Linear Regression with Rooms , Bedroom2 , Bathroom , BuildingArea Features
x=newdf[['Rooms','Bedroom2','Bathroom','BuildingArea']]
y=newdf['Price']
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=1)
ml2=LinearRegression()
ml2.fit(X_train,Y_train)
Y_predict=ml2.predict(X_test)
print(ml2.score(X_train,Y_train))
print(ml2.score(X_test,Y_test))
# Out:
# 0.3835672637328119
# 0.3661875050332968

# %%
plt.figure()
sns.scatterplot(x=Y_predict,y=(Y_test-Y_predict))
plt.show()

# %%
ml2.intercept_
# Out:
# -11394.142040480161

# %%
ml2.coef_
# Out:
# array([187657.8058745 , -22057.73026608, 209492.56562143,   1865.08343799])

# %%
plt.figure()
sns.scatterplot(x=Y_predict,y=(Y_test))
plt.show()

# %%
plt.figure()
sns.distplot((Y_test-Y_predict))
plt.show()

# %%
#Multiple Linear Regression with Rooms , Bedroom2 , Bathroom , Type ,BuildingArea Features
x=newdf[['Rooms','Bedroom2','Bathroom','Type','BuildingArea']]
y=newdf['Price']
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=1)
ml3=LinearRegression()
ml3.fit(X_train,Y_train)
Y_predict=ml3.predict(X_test)
print(ml3.score(X_train,Y_train))
print(ml3.score(X_test,Y_test))
# Out:
# 0.4111066774378018
# 0.3919180227556367

# %%
#Multiple Linear Regression with Rooms , Bedroom2 , Bathroom , Type ,YearBuilt,BuildingArea Features
x=newdf[['Rooms','Bedroom2','Bathroom','Type','YearBuilt','BuildingArea']]
y=newdf['Price']
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=1)
ml4=LinearRegression()
ml4.fit(X_train,Y_train)
Y_predict=ml4.predict(X_test)
print(ml4.score(X_train,Y_train))
print(ml4.score(X_test,Y_test))
# Out:
# 0.5079733824717702
# 0.458463933266683

# %%
#Multiple Linear Regression with All Features
x=newdf.drop('Price',axis=1)
y=newdf['Price']
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=1)
ml5=LinearRegression()
ml5.fit(X_train,Y_train)
Y_predict=ml5.predict(X_test)
print(ml5.score(X_train,Y_train))
print(ml5.score(X_test,Y_test))
# Out:
# 0.6476444560763274
# 0.5948263044386989

# %%
ml5.coef_
# Out:
# array([-3.58432460e+02, -2.09066827e-01, -1.60978513e+05, -1.22490244e+03,
#        -1.83645188e+02, -7.28296621e+02, -4.95843402e+03,  2.79447204e+04,
#         1.22304321e+05, -4.64936286e+04,  8.98686569e+02,  2.45363565e+03,
#         2.18603658e+05,  6.08541571e+04,  3.35068744e+01,  1.42056789e+03,
#        -3.26229203e+03, -7.94429752e+05,  1.01674721e+06, -2.12647305e-01])

# %%
# Score is good but not too good

# %% [markdown]
# # Apply Regularization

# %%
from sklearn.linear_model import Lasso , Ridge

# %%
#Lasso
#To check Lambda Value for Lasso 
for i in range(200,501,50):
    l1=Lasso(i)
    l1.fit(X_train,Y_train)
    print(i)
    print('Train-')
    print(l1.score(X_train,Y_train))
    print('Test-')
    print(l1.score(X_test,Y_test))
    print()
# Out:
# 200
# Train-
# 0.64761760316411
# Test-
# 0.5944278248265593
#
# 250
# Train-
# 0.6476024983268224
# Test-
# 0.5943220628784245
#
# 300
# Train-
# 0.6475840368923866
# Test-
# 0.5942138436309089
#
# 350
# Train-
# 0.6475622186795298
# Test-
# 0.5941031680631982
#
# 400
# Train-
# 0.647537044082857
# Test-
# 0.593990034275854
#
# 450
# Train-
# 0.647508512637686
# Test-
# 0.5938744443587157
#
# 500
# Train-
# 0.6474766245702974
# Test-
# 0.5937563972953659

# %%
#Ridge
#To check Lambda Value for Ridge 
for i in range(0,51,1):
    l2=Ridge(i)
    l2.fit(X_train,Y_train)
    print(i)
    print('Train-')
    print(l2.score(X_train,Y_train))
    print('Test-')
    print(l2.score(X_test,Y_test))
    print()
# Out:
# 0
# Train-
# 0.6476444560763263
# Test-
# 0.594826304438695
#
# 1
# Train-
# 0.6476183176110775
# Test-
# 0.5944245012222984
#
# 2
# Train-
# 0.6475461980827614
# Test-
# 0.5940132122414016
#
# 3
# Train-
# 0.6474362927072345
# Test-
# 0.5935962045714817
#
# 4
# Train-
# 0.6472953873514766
# Test-
# 0.5931764946933074
#
# 5
# Train-
# 0.6471291211002927
# Test-
# 0.5927564933619522
#
# 6
# Train-
# 0.6469421947423886
# Test-
# 0.5923381215349255
#
# 7
# Train-
# 0.6467385375785526
# Test-
# 0.5919229033111449
#
# 8
# Train-
# 0.6465214417555387
# Test-
# 0.5915120406259246
#
# 9
# Train-
# 0.6462936710735521
# Test-
# 0.5911064734527939
#
# 10
# Train-
# 0.6460575495792167
# Test-
# 0.590706928466818
#
# 11
# Train-
# 0.6458150340459248
# Test-
# 0.5903139584959429
#
# 12
# Train-
# 0.6455677735357028
# Test-
# 0.5899279745947549
#
# 13
# Train-
# 0.6453171585478984
# Test-
# 0.5895492721903927
#
# 14
# Train-
# 0.6450643617323591
# Test-
# 0.5891780524496453
#
# 15
# Train-
# ...

# %%
# We will take lambda value 200 for Lasso and 2 for Ridge

# %%
# Lasso - Lambda=200
l1=Lasso(200)
l1.fit(X_train,Y_train)
print('Train-')
print(l1.score(X_train,Y_train))
print('Test-')
print(l1.score(X_test,Y_test))
# Out:
# Train-
# 0.64761760316411
# Test-
# 0.5944278248265593

# %%
l1.coef_
# Out:
# array([-3.64557559e+02, -1.63786200e-01, -1.59814771e+05, -1.19373110e+03,
#        -1.84272371e+02, -7.26104422e+02, -5.04073682e+03,  2.78080887e+04,
#         1.22491945e+05, -4.65005559e+04,  9.21032903e+02,  2.19100708e+03,
#         2.18743340e+05,  6.06419196e+04,  3.36000247e+01,  1.42563443e+03,
#        -3.27770384e+03, -7.57795290e+05,  9.94452673e+05, -2.46422869e-01])

# %%
# Ridge - Lambda=2
l2=Ridge(2)
l2.fit(X_train,Y_train)
print('Train-')
print(l2.score(X_train,Y_train))
print('Test-')
print(l2.score(X_test,Y_test))
# Out:
# Train-
# 0.6475461980827614
# Test-
# 0.5940132122414016

# %%
l2.coef_
# Out:
# array([-3.70602830e+02, -1.57436104e-01, -1.59262631e+05, -1.47539249e+03,
#        -1.86480551e+02, -7.27944922e+02, -5.13806076e+03,  2.71485471e+04,
#         1.22262254e+05, -4.65863938e+04,  9.44934099e+02,  2.66031911e+03,
#         2.19312379e+05,  6.07940591e+04,  3.36844331e+01,  1.42560137e+03,
#        -3.28591340e+03, -7.43361176e+05,  9.56593857e+05, -2.57390406e-01])

# %% [markdown]
# # To check Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
#Cross Validation with Lasso
l1=Lasso(200)
l1_cross=cross_val_score(l1,x,y,cv=4)
print(l1_cross)
print(l1_cross.mean())
# Out:
# [0.60001231 0.67853068 0.62812742 0.45699322]
# 0.5909159058688074

# %%
#Cross Validation with Ridge
l2=Ridge(2)
l2_cross=cross_val_score(l2,x,y,cv=4)
print(l2_cross)
print(l2_cross.mean())
# Out:
# [0.60014199 0.67812382 0.6276915  0.45852452]
# 0.5911204560688904

# %%
# cross validation of both Lasso and Ridge are approximately same

# %%
# So we can use Lasso as well as Ridge also .
