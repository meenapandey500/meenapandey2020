# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\Rajesh\Downloads\house_price.csv")

# %%
df
# Out:
#       Unnamed: 0    Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0              0     1          60       RL         65.0     8450   Pave
# 1              1     2          20       RL         80.0     9600   Pave
# 2              2     3          60       RL         68.0    11250   Pave
# 3              3     4          70       RL         60.0     9550   Pave
# 4              4     5          60       RL         84.0    14260   Pave
# 5              5     6          50       RL         85.0    14115   Pave
# 6              6     7          20       RL         75.0    10084   Pave
# 7              7     8          60       RL          NaN    10382   Pave
# 8              8     9          50       RM         51.0     6120   Pave
# 9              9    10         190       RL         50.0     7420   Pave
# 10            10    11          20       RL         70.0    11200   Pave
# 11            11    12          60       RL         85.0    11924   Pave
# ...

# %%
df.set_index("Id",inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 25 columns):
# Unnamed: 0       1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    729.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       0.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     364.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     729.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1094.250000    70.000000    80.000000   11601.500000     7.000000
# max    1459.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   GarageArea      SalePrice
# count  1460.000000  1460.000000   1460.000000  1460.000000    1460.000000
# mean      5.575342  1971.267808   1984.865753   472.980137  180921.195890
# std       1.112799    30.202904     20.645407   213.804841   79442.502883
# ...

# %%
df.head()
# Out:
#     Unnamed: 0  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# Id
# 1            0          60       RL         65.0     8450   Pave   NaN
# 2            1          20       RL         80.0     9600   Pave   NaN
# 3            2          60       RL         68.0    11250   Pave   NaN
# 4            3          70       RL         60.0     9550   Pave   NaN
# 5            4          60       RL         84.0    14260   Pave   NaN
#
#    LotShape LandContour Utilities  ... BldgType HouseStyle OverallQual  \
# Id                                 ...
# 1       Reg         Lvl    AllPub  ...     1Fam     2Story           7
# 2       Reg         Lvl    AllPub  ...     1Fam     1Story           6
# 3       IR1         Lvl    AllPub  ...     1Fam     2Story           7
# 4       IR1         Lvl    AllPub  ...     1Fam     2Story           7
# 5       IR1         Lvl    AllPub  ...     1Fam     2Story           8
#
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# Id
# 1456        1455          60       RL         62.0     7917   Pave   NaN
# 1457        1456          20       RL         85.0    13175   Pave   NaN
# 1458        1457          70       RL         66.0     9042   Pave   NaN
# 1459        1458          20       RL         68.0     9717   Pave   NaN
# 1460        1459          20       RL         75.0     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... BldgType HouseStyle OverallQual  \
# Id                                   ...
# 1456      Reg         Lvl    AllPub  ...     1Fam     2Story           6
# 1457      Reg         Lvl    AllPub  ...     1Fam     1Story           6
# 1458      Reg         Lvl    AllPub  ...     1Fam     2Story           7
# 1459      Reg         Lvl    AllPub  ...     1Fam     1Story           5
# 1460      Reg         Lvl    AllPub  ...     1Fam     1Story           5
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# GarageArea          0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %%
df.drop(["Alley"],axis=1,inplace=True)

# %%
LotFrontage_mean=df["LotFrontage"].mean()
print(LotFrontage_mean)
# Out:
# 70.04995836802665

# %%
df["LotFrontage"].fillna(LotFrontage_mean,inplace=True)

# %%
df
# Out:
#       Unnamed: 0  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# Id
# 1              0          60       RL    65.000000     8450   Pave      Reg
# 2              1          20       RL    80.000000     9600   Pave      Reg
# 3              2          60       RL    68.000000    11250   Pave      IR1
# 4              3          70       RL    60.000000     9550   Pave      IR1
# 5              4          60       RL    84.000000    14260   Pave      IR1
# 6              5          50       RL    85.000000    14115   Pave      IR1
# 7              6          20       RL    75.000000    10084   Pave      Reg
# 8              7          60       RL    70.049958    10382   Pave      IR1
# 9              8          50       RM    51.000000     6120   Pave      Reg
# 10             9         190       RL    50.000000     7420   Pave      Reg
# 11            10          20       RL    70.000000    11200   Pave      Reg
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# GarageArea       0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %% [markdown]
# ###SKEWNESS

# %%
df.describe()
# Out:
#         Unnamed: 0   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    729.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    22.024023    9981.264932     1.382997
# min       0.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     364.750000    20.000000    60.000000    7553.500000     5.000000
# 50%     729.500000    50.000000    70.049958    9478.500000     6.000000
# 75%    1094.250000    70.000000    79.000000   11601.500000     7.000000
# max    1459.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   GarageArea      SalePrice
# count  1460.000000  1460.000000   1460.000000  1460.000000    1460.000000
# mean      5.575342  1971.267808   1984.865753   472.980137  180921.195890
# std       1.112799    30.202904     20.645407   213.804841   79442.502883
# ...

# %%
from scipy.stats import skew

# %%
#changing datatype to string
df[["OverallQual","OverallCond"]]=df[["OverallQual","OverallCond"]].astype(str)
#selecting only numerical values
df_num=df.select_dtypes(["int64","float64"])
#this will give the values from the dataframe having only integer or float dataytpes.
df_num
# Out:
#       Unnamed: 0  MSSubClass  LotFrontage  LotArea  YearBuilt  YearRemodAdd  \
# Id
# 1              0          60    65.000000     8450       2003          2003
# 2              1          20    80.000000     9600       1976          1976
# 3              2          60    68.000000    11250       2001          2002
# 4              3          70    60.000000     9550       1915          1970
# 5              4          60    84.000000    14260       2000          2000
# 6              5          50    85.000000    14115       1993          1995
# 7              6          20    75.000000    10084       2004          2005
# 8              7          60    70.049958    10382       1973          1973
# 9              8          50    51.000000     6120       1931          1950
# 10             9         190    50.000000     7420       1939          1950
# 11            10          20    70.000000    11200       1965          1965
# ...

# %%
df_num.drop(["Unnamed: 0"],axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_num
# Out:
#       MSSubClass  LotFrontage  LotArea  YearBuilt  YearRemodAdd  GarageArea  \
# Id
# 1             60    65.000000     8450       2003          2003         548
# 2             20    80.000000     9600       1976          1976         460
# 3             60    68.000000    11250       2001          2002         608
# 4             70    60.000000     9550       1915          1970         642
# 5             60    84.000000    14260       2000          2000         836
# 6             50    85.000000    14115       1993          1995         480
# 7             20    75.000000    10084       2004          2005         636
# 8             60    70.049958    10382       1973          1973         484
# 9             50    51.000000     6120       1931          1950         468
# 10           190    50.000000     7420       1939          1950         205
# 11            20    70.000000    11200       1965          1965         384
# ...

# %%
df_num.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  YearBuilt  YearRemodAdd  GarageArea  \
# Id
# 1           60         65.0     8450       2003          2003         548
# 2           20         80.0     9600       1976          1976         460
# 3           60         68.0    11250       2001          2002         608
# 4           70         60.0     9550       1915          1970         642
# 5           60         84.0    14260       2000          2000         836
#
#     SalePrice
# Id
# 1      208500
# 2      181500
# 3      223500
# 4      140000
# 5      250000

# %%
#df_num.set_index("Id",inplace=True)

# %%
df_num
# Out:
#       MSSubClass  LotFrontage  LotArea  YearBuilt  YearRemodAdd  GarageArea  \
# Id
# 1             60    65.000000     8450       2003          2003         548
# 2             20    80.000000     9600       1976          1976         460
# 3             60    68.000000    11250       2001          2002         608
# 4             70    60.000000     9550       1915          1970         642
# 5             60    84.000000    14260       2000          2000         836
# 6             50    85.000000    14115       1993          1995         480
# 7             20    75.000000    10084       2004          2005         636
# 8             60    70.049958    10382       1973          1973         484
# 9             50    51.000000     6120       1931          1950         468
# 10           190    50.000000     7420       1939          1950         205
# 11            20    70.000000    11200       1965          1965         384
# ...

# %%
for col in df_num:
    print(col,skew(df_num[col]))
# Out:
# MSSubClass 1.4062101115313512
# LotFrontage 2.382499177054863
# LotArea 12.195142125084478
# YearBuilt -0.612830724202899
# YearRemodAdd -0.5030444967597948
# GarageArea 0.1797959420587727
# SalePrice 1.880940746034036

# %%
for col in df_num:
    print(col,skew(df_num[col]))
    plt.figure(figsize=(7,7))
    sns.distplot(df_num[col])
    plt.show()
# Out:
# MSSubClass 1.4062101115313512
# LotFrontage 2.382499177054863
# LotArea 12.195142125084478
# YearBuilt -0.612830724202899
# YearRemodAdd -0.5030444967597948
# GarageArea 0.1797959420587727
# SalePrice 1.880940746034036

# %%
for col in df_num:
    if skew(df_num[col])>=1 or skew(df_num[col]<=1):
        df_num[col]=np.sqrt(df_num[col])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for col in df_num:
    print(col,skew(df_num[col]))
# Out:
# MSSubClass 0.7616639725925549
# LotFrontage 0.3678334711730094
# LotArea 4.135459203556218
# YearBuilt -0.612830724202899
# YearRemodAdd -0.5030444967597948
# GarageArea -1.59836506419671
# SalePrice 0.9421834681211159

# %%
for col in df_num:
    print(col,skew(df_num[col]))
    plt.figure()
    sns.distplot(df_num[col])
    plt.show()
# Out:
# MSSubClass 0.7616639725925549
# LotFrontage 0.3678334711730094
# LotArea 4.135459203556218
# YearBuilt -0.612830724202899
# YearRemodAdd -0.5030444967597948
# GarageArea -1.59836506419671
# SalePrice 0.9421834681211159

# %%
for col in df_num:
    plt.figure()
    sns.boxplot(data=df_num,x=col,whis=3)
    plt.show()

# %%
df_cat=df.select_dtypes("object")

# %%
df_cat
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 2          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 5          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# 6          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 7          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 8          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 9          RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 10         RL   Pave      Reg         Lvl    AllPub    Corner       Gtl
# 11         RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 12         RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# ...

# %%
df_cat["MSZoning"].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df_cat:
    Le=LabelEncoder()
    df_cat[col]=le.fit_transform(df_cat[col])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_cat.head()
# Out:
#     MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# Id
# 1          3       1         3            3          0          4          0
# 2          3       1         3            3          0          2          0
# 3          3       1         0            3          0          4          0
# 4          3       1         0            3          0          0          0
# 5          3       1         0            3          0          2          0
#
#     Neighborhood  Condition1  Condition2  BldgType  HouseStyle  OverallQual  \
# Id
# 1              5           2           2         0           5            7
# 2             24           1           2         0           2            6
# 3              5           2           2         0           5            7
# 4              6           2           2         0           5            7
# 5             15           2           2         0           5            8
#
# ...

# %% [markdown]
# ### MERGING CONTINUOUS AND CATEGORICAL DATAFRAME

# %%
df_new=pd.merge(df_num,df_cat,on="Id")

# %% [markdown]
# ### SCALING

# %%
df_new.head()
# Out:
#     MSSubClass  LotFrontage     LotArea  YearBuilt  YearRemodAdd  GarageArea  \
# Id
# 1     7.745967     8.062258   91.923882       2003          2003   23.409400
# 2     4.472136     8.944272   97.979590       1976          1976   21.447611
# 3     7.745967     8.246211  106.066017       2001          2002   24.657656
# 4     8.366600     7.745967   97.724101       1915          1970   25.337719
# 5     7.745967     9.165151  119.415242       2000          2000   28.913665
#
#      SalePrice  MSZoning  Street  LotShape  ...  LandSlope  Neighborhood  \
# Id                                          ...
# 1   456.618002         3       1         3  ...          0             5
# 2   426.028168         3       1         3  ...          0            24
# 3   472.757866         3       1         0  ...          0             5
# 4   374.165739         3       1         0  ...          0             6
# 5   500.000000         3       1         0  ...          0            15
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
for col in df_new:
    mm=MinMaxScaler()
    df_new[col]=mm.fit_transform(df_new[[col]])

# %%
df_new.head()
# Out:
#     MSSubClass  LotFrontage   LotArea  YearBuilt  YearRemodAdd  GarageArea  \
# Id
# 1     0.351574     0.265438  0.130567   0.949275      0.883333    0.621659
# 2     0.000000     0.332719  0.144720   0.753623      0.433333    0.569562
# 3     0.351574     0.279470  0.163618   0.934783      0.866667    0.654808
# 4     0.418224     0.241310  0.144123   0.311594      0.333333    0.672867
# 5     0.351574     0.349569  0.194816   0.927536      0.833333    0.767830
#
#     SalePrice  MSZoning  Street  LotShape  ...  LandSlope  Neighborhood  \
# Id                                         ...
# 1    0.395552      0.75     1.0       1.0  ...        0.0      0.208333
# 2    0.350705      0.75     1.0       1.0  ...        0.0      1.000000
# 3    0.419214      0.75     1.0       0.0  ...        0.0      0.208333
# 4    0.274670      0.75     1.0       0.0  ...        0.0      0.250000
# 5    0.459153      0.75     1.0       0.0  ...        0.0      0.625000
#
# ...

# %% [markdown]
# ### FEATURE ENGINEERING

# %%
df_new["TotalArea"]=df_new["LotArea"]+df_new["GarageArea"]

# %%
df_new.head()
# Out:
#     MSSubClass  LotFrontage   LotArea  YearBuilt  YearRemodAdd  GarageArea  \
# Id
# 1     0.351574     0.265438  0.130567   0.949275      0.883333    0.621659
# 2     0.000000     0.332719  0.144720   0.753623      0.433333    0.569562
# 3     0.351574     0.279470  0.163618   0.934783      0.866667    0.654808
# 4     0.418224     0.241310  0.144123   0.311594      0.333333    0.672867
# 5     0.351574     0.349569  0.194816   0.927536      0.833333    0.767830
#
#     SalePrice  MSZoning  Street  LotShape  ...  Neighborhood  Condition1  \
# Id                                         ...
# 1    0.395552      0.75     1.0       1.0  ...      0.208333       0.250
# 2    0.350705      0.75     1.0       1.0  ...      1.000000       0.125
# 3    0.419214      0.75     1.0       0.0  ...      0.208333       0.250
# 4    0.274670      0.75     1.0       0.0  ...      0.250000       0.250
# 5    0.459153      0.75     1.0       0.0  ...      0.625000       0.250
#
# ...
