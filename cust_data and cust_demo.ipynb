# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("Cust_data.csv")
df2=pd.read_csv("Cust_demo.csv")

# %%
top=df1[['ID','SeriousDlqin2yrs','MonthlyIncome']].head(100)

# %%
top
# Out:
#         ID  SeriousDlqin2yrs  MonthlyIncome
# 0    83236                 0        11500.0
# 1     2503                 0        14166.0
# 2   137013                 0         6733.0
# 3    51306                 0        13316.0
# 4    71937                 0         2557.0
# 5    89149                 0            NaN
# 6   140279                 0         5000.0
# 7   123541                 0         7000.0
# 8    47756                 0        11833.0
# 9   112237                 0            NaN
# 10  131169                 0        20000.0
# 11  144324                 0         6150.0
# 12   99371                 0         6200.0
# 13   59161                 0         5700.0
# 14  112957                 0            NaN
# 15   98354                 0         7500.0
# 16  130663                 0         3900.0
# 17   51766                 0         7726.0
# 18    9220                 0            NaN
# 19   95035                 0        10400.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149956 entries, 0 to 149955
# Data columns (total 8 columns):
# ID                    149956 non-null int64
# Location              149956 non-null object
# Gender                149956 non-null int64
# age                   149956 non-null int64
# Martial_Status        149956 non-null object
# NumberOfDependents    146033 non-null float64
# Own_House             149956 non-null int64
# No_Years_address      149956 non-null int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 9.2+ MB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149902 entries, 0 to 149901
# Data columns (total 10 columns):
# ID                                      149902 non-null int64
# SeriousDlqin2yrs                        149902 non-null int64
# RevolvingUtilizationOfUnsecuredLines    149902 non-null float64
# NumberOfTime30_59DaysPastDueNotWorse    149902 non-null int64
# DebtRatio                               149902 non-null float64
# MonthlyIncome                           120191 non-null float64
# NumberOfOpenCreditLinesAndLoans         149902 non-null int64
# NumberOfTimes90DaysLate                 149902 non-null int64
# NumberRealEstateLoansOrLines            149902 non-null int64
# NumberOfTime60_89DaysPastDueNotWorse    149902 non-null int64
# dtypes: float64(3), int64(7)
# memory usage: 11.4 MB

# %%
df1.isnull().sum()
# Out:
# ID                                          0
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# NumberOfTime30_59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29711
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60_89DaysPastDueNotWorse        0
# dtype: int64

# %%
#find percentage of null values in MonthlyIncome columns
df1["MonthlyIncome"].isnull().sum()/df1.shape[0]*100
# Out:
# 19.820282584621953

# %%
df1["MonthlyIncome"].unique()
# Out:
# array([11500., 14166.,  6733., ..., 14672.,  1637., 21083.])

# %%
df1["MonthlyIncome"].fillna(df1["MonthlyIncome"].mean(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# ID                                      0
# SeriousDlqin2yrs                        0
# RevolvingUtilizationOfUnsecuredLines    0
# NumberOfTime30_59DaysPastDueNotWorse    0
# DebtRatio                               0
# MonthlyIncome                           0
# NumberOfOpenCreditLinesAndLoans         0
# NumberOfTimes90DaysLate                 0
# NumberRealEstateLoansOrLines            0
# NumberOfTime60_89DaysPastDueNotWorse    0
# dtype: int64

# %%
df1
# Out:
#             ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0        83236                 0                              0.311726
# 1         2503                 0                              0.124988
# 2       137013                 0                              0.060258
# 3        51306                 0                              0.064322
# 4        71937                 0                              0.211186
# 5        89149                 0                              0.056599
# 6       140279                 0                              0.137483
# 7       123541                 0                              0.285436
# 8        47756                 0                              0.086546
# 9       112237                 0                              0.031186
# 10      131169                 0                              0.458751
# 11      144324                 0                              0.000000
# ...

# %%
df2.isnull().sum()
# Out:
# ID                       0
# Location                 0
# Gender                   0
# age                      0
# Martial_Status           0
# NumberOfDependents    3923
# Own_House                0
# No_Years_address         0
# dtype: int64

# %%
df2["NumberOfDependents"].isnull().sum()/df2.shape[0]*100
# Out:
# 2.616100722878711

# %%
df2["NumberOfDependents"].fillna(df2["NumberOfDependents"].median(),inplace=True)

# %%
df2["NumberOfDependents"].unique()
# Out:
# array([ 1.,  0.,  3.,  2.,  5.,  4.,  6.,  7.,  8., 10.,  9., 20., 13.])

# %%
df2.isnull().sum()
# Out:
# ID                    0
# Location              0
# Gender                0
# age                   0
# Martial_Status        0
# NumberOfDependents    0
# Own_House             0
# No_Years_address      0
# dtype: int64

# %%
df2
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 0         4532         Gandhinagar,Gujarat       0   39         Single
# 1       148736    Hyderabad,Andhra Pradesh       0   52        Married
# 2        95965     Shimla,Himachal Pradesh       0   62        Married
# 3        61759                 Srinagar,JK       0   42         Single
# 4        49806              Imphal,Manipur       0   41         Single
# 5       139942                 Srinagar,JK       0   59         Single
# 6       131136              Aizawl,Mizoram       0   37         Single
# 7        87969             Kohima,Nagaland       1   63        Married
# 8       124554       Bhopal,Madhya Pradesh       0   59         Single
# 9        77997                 Srinagar,JK       1   55         Single
# 10       36272         Gandhinagar,Gujarat       0   47         Single
# 11      126015                 Patna,Bihar       0   68         Single
# ...

# %%
#cars["normalized-losses"] = cars["normalized-losses"].astype("float")
df2['NumberOfDependents']=df2['NumberOfDependents'].astype('int64')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149956 entries, 0 to 149955
# Data columns (total 8 columns):
# ID                    149956 non-null int64
# Location              149956 non-null object
# Gender                149956 non-null int64
# age                   149956 non-null int64
# Martial_Status        149956 non-null object
# NumberOfDependents    149956 non-null int64
# Own_House             149956 non-null int64
# No_Years_address      149956 non-null int64
# dtypes: int64(6), object(2)
# memory usage: 9.2+ MB

# %%
df1['MonthlyIncome']=df1['MonthlyIncome'].astype('int64')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149902 entries, 0 to 149901
# Data columns (total 10 columns):
# ID                                      149902 non-null int64
# SeriousDlqin2yrs                        149902 non-null int64
# RevolvingUtilizationOfUnsecuredLines    149902 non-null float64
# NumberOfTime30_59DaysPastDueNotWorse    149902 non-null int64
# DebtRatio                               149902 non-null float64
# MonthlyIncome                           149902 non-null int64
# NumberOfOpenCreditLinesAndLoans         149902 non-null int64
# NumberOfTimes90DaysLate                 149902 non-null int64
# NumberRealEstateLoansOrLines            149902 non-null int64
# NumberOfTime60_89DaysPastDueNotWorse    149902 non-null int64
# dtypes: float64(2), int64(8)
# memory usage: 11.4 MB

# %%
plt.figure(figsize=(6,6))

sns.boxplot(data=df1,x="MonthlyIncome")

plt.show()

# %%
Income_bucket=df1[(df1['MonthlyIncome']) > 1000000]

# %%
Income_bucket
# Out:
#             ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 99668    73764                 0                              0.007328
# 113405  111366                 0                              0.163856
# 115031   50641                 0                              0.469025
# 142534  137141                 0                              0.000000
#
#         NumberOfTime30_59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 99668                                      0   0.001470        3008750
# 113405                                     0   0.004013        1560100
# 115031                                     1   0.004537        1072500
# 142534                                     0   0.002776        1794060
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 99668                                10                        0
# 113405                               12                        0
# ...

# %%
Income_bucket=df1[(df1['MonthlyIncome'] > 500000) & (df1['MonthlyIncome'] <1000000)]

# %%
Income_bucket
# Out:
#             ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 2397    119137                 0                              0.151329
# 21064    93565                 0                              0.071628
# 60619    35974                 0                              0.439684
# 86923    37079                 0                              0.000000
# 87656   137427                 0                              0.079804
# 96933    96550                 0                              0.064155
# 129123  123292                 0                              0.226333
# 139394  122544                 0                              0.041599
#
#         NumberOfTime30_59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 2397                                       0   0.001313         649587
# 21064                                      0   0.008268         702500
# 60619                                      0   0.004003         582369
# ...

# %%
Income_bucket=df1[(df1['MonthlyIncome'] >200000) & (df1['MonthlyIncome'] <500000)]

# %%
Income_bucket
# Out:
#             ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 18874   128749                 0                              0.000000
# 31556   106341                 0                              0.006473
# 36045    23700                 0                              0.196404
# 41814     4044                 0                              0.007390
# 41815    67679                 1                              0.000000
# 60548    17374                 0                              1.000000
# 60928    43345                 0                              0.151357
# 72024    25340                 0                              0.017000
# 77661    17598                 0                              0.000000
# 101073   88464                 0                              0.176144
# 116171     267                 0                              0.007983
# 120025  124636                 0                              0.036010
# ...

# %%
Income_bucket=df1[(df1['MonthlyIncome'] > 100000) & (df1['MonthlyIncome'] <200000)]

# %%
Income_bucket
# Out:
#             ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 629      40737                 0                              0.000559
# 1312     62383                 0                              0.746407
# 7877     87280                 0                              0.255302
# 8686     77169                 0                              0.195705
# 11778   109873                 0                              0.948003
# 14354    42078                 0                              0.025474
# 14865    95271                 0                              0.056340
# 15377    79989                 0                              0.362211
# 16388    90906                 0                              0.039414
# 19654   117421                 0                              0.828866
# 24949    86630                 0                              0.108568
# 31776   103284                 0                              0.320561
# ...

# %%
Income_bucket=df1[(df1['MonthlyIncome']) < 100000]

# %%
Income_bucket
# Out:
#             ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0        83236                 0                              0.311726
# 1         2503                 0                              0.124988
# 2       137013                 0                              0.060258
# 3        51306                 0                              0.064322
# 4        71937                 0                              0.211186
# 5        89149                 0                              0.056599
# 6       140279                 0                              0.137483
# 7       123541                 0                              0.285436
# 8        47756                 0                              0.086546
# 9       112237                 0                              0.031186
# 10      131169                 0                              0.458751
# 11      144324                 0                              0.000000
# ...

# %%
df2.head()
# Out:
#        ID                  Location  Gender  age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat       0   39         Single
# 1  148736  Hyderabad,Andhra Pradesh       0   52        Married
# 2   95965   Shimla,Himachal Pradesh       0   62        Married
# 3   61759               Srinagar,JK       0   42         Single
# 4   49806            Imphal,Manipur       0   41         Single
#
#    NumberOfDependents  Own_House  No_Years_address
# 0                   1          1                 3
# 1                   0          0                 3
# 2                   0          0                 2
# 3                   1          1                 1
# 4                   1          0                 3

# %%
Life_Stage_bucket_student=df2[(df2['age']) < 22]

# %%
Life_Stage_bucket_student
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 266      35313   Thiruvananthapuram,Kerala       1   21         Single
# 415      57858              Aizawl,Mizoram       0   21         Single
# 1008     24461          Shillong,Meghalaya       1   21         Single
# 1294     58624                Dispur,Assam       0   21         Single
# 3771     68816         Kolkata,West Bengal       0   21         Single
# 3808     12990    Hyderabad,Andhra Pradesh       0   21         Single
# 5319     29398                 Patna,Bihar       0   21         Single
# 5854    123578         Raipur,Chhattisgarh       0   21        Married
# 6548      5344          Chandigarh,Haryana       0   21         Single
# 6709    105734     Shimla,Himachal Pradesh       0   21         Single
# 7254     64512                Dispur,Assam       0   21        Married
# 7614     18279             Kohima,Nagaland       1   21        Married
# ...

# %%
Life_Stage_bucket_UnMarried_Employed=df2[(df2['age'] > 23) & (df2['age'] <27)]

# %%
Life_Stage_bucket_UnMarried_Employed
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 33       82371   Thiruvananthapuram,Kerala       0   26        Married
# 158     126387          Chandigarh,Haryana       0   25        Married
# 163      87411                    Jammu,JK       0   25        Married
# 182      78730         Gandhinagar,Gujarat       0   24         Single
# 440      42313          Chandigarh,Haryana       0   24         Single
# 512     103015                 Patna,Bihar       1   26         Single
# 672     133058     Shimla,Himachal Pradesh       0   26        Married
# 726      21349         Raipur,Chhattisgarh       0   26         Single
# 734     140555          Chandigarh,Haryana       1   25        Married
# 736     108793                Dispur,Assam       0   26         Single
# 866      11824  Itanagar,Arunachal Pradesh       0   24         Single
# 992      61327     Shimla,Himachal Pradesh       0   26        Married
# ...

# %%
Life_Stage_bucket_Married_with_Young_Kids=df2[(df2['age'] > 27) & (df2['age'] <40)]

# %%
Life_Stage_bucket_Married_with_Young_Kids
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 0         4532         Gandhinagar,Gujarat       0   39         Single
# 6       131136              Aizawl,Mizoram       0   37         Single
# 12         603         Raipur,Chhattisgarh       1   39         Single
# 16      146493            Ranchi,Jharkhand       1   36         Single
# 18       45050              Aizawl,Mizoram       0   34         Single
# 26       71634            Ranchi,Jharkhand       0   30         Single
# 28       26404         Kolkata,West Bengal       0   33        Married
# 31       24104         Kolkata,West Bengal       0   38         Single
# 38      131602          Chennai,Tamil Nadu       0   39        Married
# 42      137858          Chennai,Tamil Nadu       0   34        Married
# 50       57715   Thiruvananthapuram,Kerala       1   39        Married
# 58      130630              Aizawl,Mizoram       0   35         Single
# ...

# %%
Life_Stage_bucket_Pre_Retired=df2[(df2['age'] > 40) & (df2['age'] <60)]

# %%
Life_Stage_bucket_Pre_Retired
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 1       148736    Hyderabad,Andhra Pradesh       0   52        Married
# 3        61759                 Srinagar,JK       0   42         Single
# 4        49806              Imphal,Manipur       0   41         Single
# 5       139942                 Srinagar,JK       0   59         Single
# 8       124554       Bhopal,Madhya Pradesh       0   59         Single
# 9        77997                 Srinagar,JK       1   55         Single
# 10       36272         Gandhinagar,Gujarat       0   47         Single
# 17      109903     Shimla,Himachal Pradesh       0   43         Single
# 20       85299       Bhopal,Madhya Pradesh       0   46         Single
# 23       37592                 Srinagar,JK       0   58        Married
# 25        1482                 Srinagar,JK       0   53         Single
# 27       46958  Bhubaneswar,Odisha(Orissa)       1   49        Married
# ...

# %%
Life_Stage_bucket_Retired=df2[(df2['age']) > 60]

# %%
Life_Stage_bucket_Retired
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 2        95965     Shimla,Himachal Pradesh       0   62        Married
# 7        87969             Kohima,Nagaland       1   63        Married
# 11      126015                 Patna,Bihar       0   68         Single
# 13        3643     Shimla,Himachal Pradesh       0   63         Single
# 14       29132   Thiruvananthapuram,Kerala       0   63         Single
# 15       86255         Raipur,Chhattisgarh       1   76         Single
# 21       54012          Chandigarh,Haryana       0   68        Married
# 24       34189                    Jammu,JK       0   80         Single
# 30       32733                 Srinagar,JK       1   74         Single
# 32       71815     Shimla,Himachal Pradesh       1   69        Married
# 34       19649         Gandhinagar,Gujarat       1   62        Married
# 37       52876         Raipur,Chhattisgarh       1   79         Single
# ...

# %%
sort=df1[['MonthlyIncome']].head(20)

# %%
sort
# Out:
#     MonthlyIncome
# 0           11500
# 1           14166
# 2            6733
# 3           13316
# 4            2557
# 5            6670
# 6            5000
# 7            7000
# 8           11833
# 9            6670
# 10          20000
# 11           6150
# 12           6200
# 13           5700
# 14           6670
# 15           7500
# 16           3900
# 17           7726
# 18           6670
# 19          10400

# %%
df1.head()
# Out:
#        ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0   83236                 0                              0.311726
# 1    2503                 0                              0.124988
# 2  137013                 0                              0.060258
# 3   51306                 0                              0.064322
# 4   71937                 0                              0.211186
#
#    NumberOfTime30_59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     0   0.296409          11500
# 1                                     0   0.115903          14166
# 2                                     0   0.515147           6733
# 3                                     0   0.165127          13316
# 4                                     0   0.022283           2557
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               12                        0
# ...

# %%
df2.head()
# Out:
#        ID                  Location  Gender  age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat       0   39         Single
# 1  148736  Hyderabad,Andhra Pradesh       0   52        Married
# 2   95965   Shimla,Himachal Pradesh       0   62        Married
# 3   61759               Srinagar,JK       0   42         Single
# 4   49806            Imphal,Manipur       0   41         Single
#
#    NumberOfDependents  Own_House  No_Years_address
# 0                   1          1                 3
# 1                   0          0                 3
# 2                   0          0                 2
# 3                   1          1                 1
# 4                   1          0                 3

# %%
df2.shape
# Out:
# (149956, 8)

# %%
df1.shape
# Out:
# (149902, 10)

# %%
merged_inner = pd.merge(left=df1,right=df2, left_on='ID', right_on='ID')
# In this case `species_id` is the only column name in  both dataframes, so if we skippd `left_on`
# And `right_on` arguments we would still get the same result

# What's the size of the output data?
merged_inner.shape
# Out:
# (149858, 17)

# %%
merged_left = pd.merge(left=df1,right=df2, how='left', left_on='ID', right_on='ID')

merged_left.shape
# Out:
# (149902, 17)

# %%
merged_left1 = pd.merge(left=df1,right=df2,how=df1["ID"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-63326d1e804b> in <module>
# ----> 1 merged_left1 = pd.merge(left=df1,right=df2,how=df1["ID"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      46                          copy=copy, indicator=indicator,
#      47                          validate=validate)
# ---> 48     return op.get_result()
#      49
#      50
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
# ...
