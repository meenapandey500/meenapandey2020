# %%
import pandas as pd

# %%
#use of pandas
'''1. Cleaning data
   2. data processing
   3. Exploring the data
   4.  collecting the data '''
# Out:
# '1. Cleaning data\n   2. data processing\n   3. Exploring the data\n   4.  collecting the data '

# %%
#There are 2 types of data structure in pandas
#1. Series
#2. DataFrame

# %%
#1. Series : create a 1D array
#create a list
data=[10,89,34,56,78,97,35]
#convert in Series
a=pd.Series(data)

# %%
print(a)
# Out:
# 0    10
# 1    89
# 2    34
# 3    56
# 4    78
# 5    97
# 6    35
# dtype: int64

# %%
a[2]
# Out:
# 34

# %%
#create a list
data=[10,89,34,56,78,97,35]
#convert in Series
a=pd.Series(data)
index=['a','b','c','d','e','f','g']
#convert in Series
a=pd.Series(data,index)

# %%
print(a)
# Out:
# a    10
# b    89
# c    34
# d    56
# e    78
# f    97
# g    35
# dtype: int64

# %%
a['c']
# Out:
# 34

# %%
#create dictionary
d={'a':10,'b':20,'c':30,'d':50}
#converts this dictionary into Series
A=pd.Series(d)
print(A)
# Out:
# a    10
# b    20
# c    30
# d    50
# dtype: int64

# %%
#DataFrame : its create 2D means 2 dimensional array means to create a table
#table means to hold data in the form of rows and columns

# %%
#create dictionary
student={'Name':['Anu Agrawal','Renu Pandey','Seema Sharma'],'Age':[23,21,25],
        'City':['Mumbai','Nasik','Pune']}

# %%
#converts student dictionary into DataFrame
S=pd.DataFrame(student)

# %%
print(S)
# Out:
#            Name  Age    City
# 0   Anu Agrawal   23  Mumbai
# 1   Renu Pandey   21   Nasik
# 2  Seema Sharma   25    Pune

# %%
#To access data from dataframe S 
#To access name of all student
S["Name"]
# Out:
# 0     Anu Agrawal
# 1     Renu Pandey
# 2    Seema Sharma
# Name: Name, dtype: object

# %%
#object means string type data

# %%
#Access multiple columns then use [[ ]] 2D means 2 dimensional array
#access Name and  City of all student
S[["Name","City"]]
# Out:
#            Name    City
# 0   Anu Agrawal  Mumbai
# 1   Renu Pandey   Nasik
# 2  Seema Sharma    Pune

# %%
S
# Out:
#            Name  Age    City
# 0   Anu Agrawal   23  Mumbai
# 1   Renu Pandey   21   Nasik
# 2  Seema Sharma   25    Pune

# %%
#access particular row 
#access all details of 1stindex  row
S.iloc[1] #if access row from dataframe then use iloc command means index loca
# Out:
# Name    Renu Pandey
# Age              21
# City          Nasik
# Name: 1, dtype: object

# %%
print(S)
# Out:
#            Name  Age    City
# 0   Anu Agrawal   23  Mumbai
# 1   Renu Pandey   21   Nasik
# 2  Seema Sharma   25    Pune

# %%
#access the only Name of 1st index
S.iloc[1,0] #here 1 means row and 0 means col
# Out:
# 'Renu Pandey'

# %%
S.loc[1,"Name"] #loc if given row index and col name
# Out:
# 'Renu Pandey'

# %%
S["Name"][1]  #dataframename["colname"][rowindex]
# Out:
# 'Renu Pandey'

# %%
#access data use slicing

# %%
S
# Out:
#            Name  Age    City
# 0   Anu Agrawal   23  Mumbai
# 1   Renu Pandey   21   Nasik
# 2  Seema Sharma   25    Pune

# %%
S.iloc[0:2,1:]  #[row start:rowstop-1 , colstart:colstop-1]
# Out:
#    Age    City
# 0   23  Mumbai
# 1   21   Nasik

# %%
S.iloc[1: ,0:2]  #start row=1 and stop=till end and col start=0 and stop=2-1=1
# Out:
#            Name  Age
# 1   Renu Pandey   21
# 2  Seema Sharma   25

# %%
#csv : comma separate values ,csv is the extension of file
#This file hold data in the form of rows and columns means tabular form
#its hold huge amt of data and processsing is very fast as comparaed to excel
#file or sql data 
#less memory required in csv file

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Rajesh'

# %%
#To load csv file
df=pd.read_csv("automobile_data.csv") 
#read_csv( ) inbuilt function , to read csv file and store in object for eg. df

# %%
#How many rows and columns then use shape method
df.shape
# Out:
# (205, 15)

# %%
df.head(10) #to display 5 records from top
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
# 5          2                 ?         audi       gas        sedan
# 6          1               158         audi       gas        sedan
# 7          1                 ?         audi       gas        wagon
# 8          1               158         audi       gas        sedan
# 9          0                 ?         audi       gas    hatchback
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# ...

# %%
df.tail() #to display 5 records from bottom
# Out:
#      symboling normalized-losses   make fuel-type body-style drive-wheels  \
# 200         -1                95  volvo       gas      sedan          rwd
# 201         -1                95  volvo       gas      sedan          rwd
# 202         -1                95  volvo       gas      sedan          rwd
# 203         -1                95  volvo    diesel      sedan          rwd
# 204         -1                95  volvo       gas      sedan          rwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 200           front   68.9    55.5         ohc          141        114
# 201           front   68.8    55.5         ohc          141        160
# 202           front   68.9    55.5        ohcv          173        134
# 203           front   68.9    55.5         ohc          145        106
# 204           front   68.9    55.5         ohc          141        114
#
#      city-mpg  highway-mpg  price
# 200        23           28  16845
# ...

# %%
df.info() #to display all details of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# width                205 non-null float64
# height               205 non-null float64
# engine-type          205 non-null object
# engine-size          205 non-null int64
# horsepower           205 non-null object
# city-mpg             205 non-null int64
# highway-mpg          205 non-null int64
# price                205 non-null int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 24.1+ KB

# %%
#check null value in dataset
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df["make"]
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
# 5             audi
# 6             audi
# 7             audi
# 8             audi
# 9             audi
# 10             bmw
# 11             bmw
# 12             bmw
# 13             bmw
# 14             bmw
# 15             bmw
# 16             bmw
# 17             bmw
# 18       chevrolet
# 19       chevrolet
# 20       chevrolet
# 21           dodge
# 22           dodge
# 23           dodge
# 24           dodge
# 25           dodge
# 26           dodge
# 27           dodge
# 28           dodge
# 29           dodge
#           ...
# 175         toyota
# 176         toyota
# 177         toyota
# 178         toyota
# 179         toyota
# 180         toyota
# 181         toyota
# 182     volkswagen
# 183     volkswagen
# 184     volkswagen
# 185     volkswagen
# 186     volkswagen
# 187     volkswagen
# 188     volkswagen
# 189     volkswagen
# 190     volkswagen
# ...

# %%
#How many unique value
df["make"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
#How many cars of multiple companies
df["make"].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# bmw               8
# mercedes-benz     8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
df["fuel-type"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df["fuel-type"].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64

# %%
df["fuel-type"].value_counts()["gas"] #only count gas
# Out:
# 185

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
#to show highest price of car
df["price"].max()
# Out:
# 45400

# %%
#to show record no. whose maximum price of car
df["price"].idxmax()
# Out:
# 74

# %%
#To display all details of 74th record no. whose max price
df.iloc[74]
# Out:
# symboling                        1
# normalized-losses                ?
# make                 mercedes-benz
# fuel-type                      gas
# body-style                 hardtop
# drive-wheels                   rwd
# engine-location              front
# width                           72
# height                        55.4
# engine-type                   ohcv
# engine-size                    304
# horsepower                     184
# city-mpg                        14
# highway-mpg                     16
# price                        45400
# Name: 74, dtype: object

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
#conditional filtering 
#Get all the rows where the body style =hatchback
df[df["body-style"]=="hatchback"]  #df[index] index apply condition
# Out:
#      symboling normalized-losses         make fuel-type body-style  \
# 2            1                 ?  alfa-romero       gas  hatchback
# 9            0                 ?         audi       gas  hatchback
# 18           2               121    chevrolet       gas  hatchback
# 19           1                98    chevrolet       gas  hatchback
# 21           1               118        dodge       gas  hatchback
# 22           1               118        dodge       gas  hatchback
# 23           1               118        dodge       gas  hatchback
# 24           1               148        dodge       gas  hatchback
# 29           3               145        dodge       gas  hatchback
# 30           2               137        honda       gas  hatchback
# 31           2               137        honda       gas  hatchback
# 32           1               101        honda       gas  hatchback
# 33           1               101        honda       gas  hatchback
# ...

# %%
df[df["fuel-type"]=="diesel"]
# Out:
#      symboling normalized-losses           make fuel-type body-style  \
# 63           0                 ?          mazda    diesel      sedan
# 66           0                 ?          mazda    diesel      sedan
# 67          -1                93  mercedes-benz    diesel      sedan
# 68          -1                93  mercedes-benz    diesel      wagon
# 69           0                93  mercedes-benz    diesel    hardtop
# 70          -1                93  mercedes-benz    diesel      sedan
# 90           1               128         nissan    diesel      sedan
# 108          0               161         peugot    diesel      sedan
# 110          0                 ?         peugot    diesel      wagon
# 112          0               161         peugot    diesel      sedan
# 114          0                 ?         peugot    diesel      wagon
# 116          0               161         peugot    diesel      sedan
# 158          0                91         toyota    diesel      sedan
# ...

# %%
#what is the Total price for each category of fuel-type ?
df.groupby("fuel-type")["price"].sum()
# Out:
# fuel-type
# diesel     316763
# gas       2394870
# Name: price, dtype: int64

# %%
d=df[df["fuel-type"]=="diesel"]

# %%
d["price"].sum()
# Out:
# 316763

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
df.groupby(["body-style","fuel-type"])["price"].mean() #mean()  average
# Out:
# body-style   fuel-type
# convertible  gas          21890.500000
# hardtop      diesel       28176.000000
#              gas          21356.000000
# hatchback    diesel        7788.000000
#              gas          10048.086957
# sedan        diesel       14774.400000
#              gas          14451.864198
# wagon        diesel       19727.666667
#              gas          11368.909091
# Name: price, dtype: float64

# %%
#To unhide the rows
pd.set_option('display.max_rows',None)  #columns

# %%
df
# Out:
#      symboling normalized-losses           make fuel-type   body-style  \
# 0            3                 ?    alfa-romero       gas  convertible
# 1            3                 ?    alfa-romero       gas  convertible
# 2            1                 ?    alfa-romero       gas    hatchback
# 3            2               164           audi       gas        sedan
# 4            2               164           audi       gas        sedan
# 5            2                 ?           audi       gas        sedan
# 6            1               158           audi       gas        sedan
# 7            1                 ?           audi       gas        wagon
# 8            1               158           audi       gas        sedan
# 9            0                 ?           audi       gas    hatchback
# 10           2               192            bmw       gas        sedan
# 11           0               192            bmw       gas        sedan
# ...
